# %%
from rstar import TestRunner as RStarTestRunner


TR = RStarTestRunner(
    [
        {
            'label': "don't know",
            'w': 2,
            'delta': 3,
            'k':  20,
            'max_steps': 100
        }
    ],
    [
        ('data/AR0044SR.map', 'empty', 120),
        ('data/Berlin_0_256.map', 'city', 60),
    ]
)
TR.run()
TR.datas[0].test_results_df.to_csv('random_results.csv')
# Out:
# ...
# 100%|██████████| 60/60 [01:25<00:00,  1.42s/it]

# %%
TR.datas[0].test_results_df.describe()
# Out:
#            length  expected_length     expansions          steps  \
# count  180.000000       180.000000     180.000000     180.000000
# mean   183.565436       171.905853    4794.422222    6638.261111
# std    110.433962       101.019992   27410.364808   37894.719152
# min      2.000000         2.000000       2.000000       3.000000
# 25%     90.191125        86.029960     132.000000     178.250000
# 50%    180.929978       171.515765     278.500000     378.000000
# 75%    275.050036       258.889610     519.750000     706.250000
# max    432.333044       365.244733  267172.000000  369104.000000
#
#        nodes_created        memory        time
# count   1.800000e+02    180.000000  180.000000
# mean    3.453948e+04   2484.738889    0.493715
# std     1.983246e+05   5506.511139    2.801116
# min     1.000000e+01     19.000000    0.000000
# 25%     9.690000e+02    545.250000    0.013983
# 50%     2.031500e+03   1148.000000    0.030722
# 75%     3.770250e+03   1941.750000    0.055459
# ...
